# %% [markdown]
# <a href="https://colab.research.google.com/github/mindjobs/Ecerlab/blob/main/Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# EDA básico en Python – Simulador ChileValora

# Paso 1: Importar librerías
import pandas as pd
import matplotlib.pyplot as plt

# Paso 2: Crear un dataset de ejemplo
data = {
    'Edad': [22, 25, 47, 52, 46, 56, 55, 60],
    'Salario': [250000, 300000, 800000, 1200000, 750000, 1100000, 1000000, 1300000],
    'Género': ['M', 'F', 'M', 'F', 'F', 'M', 'F', 'M']
}
df = pd.DataFrame(data)

# Paso 3: Mostrar el dataset
print("Vista del dataset:")
print(df)

# Paso 4: Análisis estadístico básico
print("\nEstadísticas descriptivas:")
print(df.describe())


# Paso 5: Gráfico de dispersión
plt.scatter(df['Edad'], df['Salario'], c='green', s=70)
plt.title('Relación entre Edad y Salario')
plt.xlabel('Edad')
plt.ylabel('Salario (CLP)')
plt.grid(True)
plt.show()
# Out:
# Vista del dataset:
#    Edad  Salario Género
# 0    22   250000      M
# 1    25   300000      F
# 2    47   800000      M
# 3    52  1200000      F
# 4    46   750000      F
# 5    56  1100000      M
# 6    55  1000000      F
# 7    60  1300000      M
#
# Estadísticas descriptivas:
#             Edad       Salario
# count   8.000000  8.000000e+00
# mean   45.375000  8.375000e+05
# std    14.282232  3.934735e+05
# min    22.000000  2.500000e+05
# 25%    40.750000  6.375000e+05
# 50%    49.500000  9.000000e+05
# 75%    55.250000  1.125000e+06
# max    60.000000  1.300000e+06
